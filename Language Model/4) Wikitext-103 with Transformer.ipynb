# %% [markdown]
# [Data Set link](https://blog.einstein.ai/the-wikitext-long-term-dependency-language-modeling-dataset/)

# %%
# !wget https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-103-v1.zip
# !unzip ./wikitext-103-v1.zip
# Out:
# --2019-08-30 15:46:18--  https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-103-v1.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.134.85
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.134.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190229076 (181M) [application/zip]
# Saving to: ‘wikitext-103-v1.zip’
#
# wikitext-103-v1.zip 100%[===================>] 181.42M  46.0MB/s    in 4.4s
#
# 2019-08-30 15:46:23 (41.5 MB/s) - ‘wikitext-103-v1.zip’ saved [190229076/190229076]
#
# Archive:  ./wikitext-103-v1.zip
#    creating: wikitext-103/
#   inflating: wikitext-103/wiki.test.tokens
#   inflating: wikitext-103/wiki.valid.tokens
#   inflating: wikitext-103/wiki.train.tokens

# %%
# !wget https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-2-v1.zip
# !unzip ./wikitext-2-v1.zip

# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
argsdata = './wikitext-103' # or './wikitext-103'
argsbatch_size = 30
argsemsize=200
argsnhead=2
argsnhid=200
argsnlayers=2
argsdropout=0.4
argslog_interval=200
argseval_interval=5000
argsclip=0.25
argsseed=42
argsbptt=35
argscuda=True
argslr=5
argsepochs=2
argstemperature = 1.0
argssave='./model.pt'
argscheckpoint = './model.pt'
argsoutf='generated.txt'
argswords=300

# %%
import os
import math
import time
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
from io import open

class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path):
        self.dictionary = Dictionary()
        self.train = self.tokenize(os.path.join(path, 'wiki.train.tokens'))
        self.valid = self.tokenize(os.path.join(path, 'wiki.valid.tokens'))
        self.test = self.tokenize(os.path.join(path, 'wiki.test.tokens'))

    def tokenize(self, path):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding="utf8") as f:
            for line in f:
                words = line.split() + ['<eos>']
                for word in words:
                    self.dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r', encoding="utf8") as f:
            idss = []
            for line in f:
                words = line.split() + ['<eos>']
                ids = []
                for word in words:
                    ids.append(self.dictionary.word2idx[word])
                idss.append(torch.tensor(ids).type(torch.int64))
            ids = torch.cat(idss)

        return ids

# %%
# Temporarily leave PositionalEncoding module here. Will be moved somewhere else.
class PositionalEncoding(nn.Module):
    r"""Inject some information about the relative or absolute position of the tokens
        in the sequence. The positional encodings have the same dimension as
        the embeddings, so that the two can be summed. Here, we use sine and cosine
        functions of different frequencies.
    .. math::
        \text{PosEncoder}(pos, 2i) = sin(pos/10000^(2i/d_model))
        \text{PosEncoder}(pos, 2i+1) = cos(pos/10000^(2i/d_model))
        \text{where pos is the word position and i is the embed idx)
    Args:
        d_model: the embed dim (required).
        dropout: the dropout value (default=0.1).
        max_len: the max. length of the incoming sequence (default=5000).
    Examples:
        >>> pos_encoder = PositionalEncoding(d_model)
    """

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        r"""Inputs of forward function
        Args:
            x: the sequence fed to the positional encoder model (required).
        Shape:
            x: [sequence length, batch size, embed dim]
            output: [sequence length, batch size, embed dim]
        Examples:
            >>> output = pos_encoder(x)
        """
        
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class TransformerModel(nn.Module):
    """Container module with an encoder, a recurrent or transformer module, and a decoder."""

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        try:
            from torch.nn import TransformerEncoder, TransformerEncoderLayer
        except:
            raise ImportError('TransformerEncoder module does not exist in PyTorch 1.1 or lower.')
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)
        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src, has_mask=True):
        if has_mask:
            device = src.device
            if self.src_mask is None or self.src_mask.size(0) != len(src):
                mask = self._generate_square_subsequent_mask(len(src)).to(device)
                self.src_mask = mask
        else:
            self.src_mask = None

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return F.log_softmax(output, dim=-1)

# %%
# %%time
# Set the random seed manually for reproducibility.
torch.manual_seed(argsseed)
if torch.cuda.is_available():
    if not argscuda:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")

device = torch.device("cuda" if argscuda else "cpu")
###############################################################################
# Load data
###############################################################################

if(os.path.exists('./corpus')):
    with open('corpus', 'rb') as data_file:
        corpus = pickle.load(data_file)
else:
    corpus = Corpus(argsdata)
    with open('corpus', 'wb') as data_file:
        pickle.dump(corpus, data_file)

ntokens = len(corpus.dictionary)
# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

eval_batch_size = 50
train_data = batchify(corpus.train, argsbatch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
# Out:
# CPU times: user 1min 52s, sys: 4.6 s, total: 1min 56s
# Wall time: 2min 4s

# %%
def print_gentext():
    input = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)
    with torch.no_grad():  # no tracking history
        for i in range(argswords):
            output = model(input, False)
            word_weights = output[-1].squeeze().div(argstemperature).exp().cpu()
            word_idx = torch.multinomial(word_weights, 1)[0]
            word_tensor = torch.Tensor([[word_idx]]).long().to(device)
            input = torch.cat([input, word_tensor], 0)
            word = corpus.dictionary.idx2word[word_idx]
            print(word + ('\n' if i % 20 == 19 else ' '),end='')

def evaluate1():
    global best_val_loss
    global lr
    val_loss = evaluate(val_data)
    print('-' * 89)
    print('| epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
            'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                       val_loss, math.exp(val_loss)))
    print('-' * 89)
    print('Generated Text:')
    print_gentext()
    # Save the model if the validation loss is the best we've seen so far.
    if not best_val_loss or val_loss < best_val_loss:
        with open(argssave, 'wb') as f:
            torch.save(model, f)
        best_val_loss = val_loss
    else:
        # Anneal the learning rate if no improvement has been seen in the validation dataset.
        lr /= 4.0

# %%
###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)

model = TransformerModel(ntokens, argsemsize, argsnhead, argsnhid, argsnlayers, argsdropout).to(device)

criterion = nn.CrossEntropyLoss()
###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""

    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length args.bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    seq_len = min(argsbptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target


def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = len(corpus.dictionary)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, argsbptt):
            data, targets = get_batch(data_source, i)
            output = model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)


def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, argsbptt)):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        model.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()

        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm_(model.parameters(), argsclip)
        for p in model.parameters():
            p.data.add_(-lr, p.grad.data)
        
        total_loss += loss.item()
        if batch% argseval_interval == 0 and batch > 0:
            evaluate1()
            
        if batch % argslog_interval == 0 and batch > 0:
            cur_loss = total_loss / argslog_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // argsbptt, lr,
                elapsed * 1000 / argslog_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# Loop over epochs.
lr = argslr
best_val_loss = None

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, argsepochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(val_data)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        print('Generated Text:')
        print_gentext()
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(argssave, 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 4.0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')

# Load the best saved model.
with open(argssave, 'rb') as f:
    model = torch.load(f)

# Run on test data.
test_loss = evaluate(test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# | epoch   1 |   200/98311 batches | lr 5.00 | ms/batch 134.72 | loss  9.00 | ppl  8095.04
# | epoch   1 |   400/98311 batches | lr 5.00 | ms/batch 130.10 | loss  7.94 | ppl  2816.82
# | epoch   1 |   600/98311 batches | lr 5.00 | ms/batch 130.19 | loss  7.58 | ppl  1955.19
# | epoch   1 |   800/98311 batches | lr 5.00 | ms/batch 130.11 | loss  7.31 | ppl  1496.95
# | epoch   1 |  1000/98311 batches | lr 5.00 | ms/batch 130.22 | loss  7.16 | ppl  1283.49
# | epoch   1 |  1200/98311 batches | lr 5.00 | ms/batch 130.03 | loss  7.07 | ppl  1179.68
# | epoch   1 |  1400/98311 batches | lr 5.00 | ms/batch 129.98 | loss  7.01 | ppl  1103.22
# | epoch   1 |  1600/98311 batches | lr 5.00 | ms/batch 130.01 | loss  6.87 | ppl   965.58
# | epoch   1 |  1800/98311 batches | lr 5.00 | ms/batch 129.97 | loss  6.89 | ppl   978.35
# | epoch   1 |  2000/98311 batches | lr 5.00 | ms/batch 130.01 | loss  6.81 | ppl   909.36
# | epoch   1 |  2200/98311 batches | lr 5.00 | ms/batch 130.09 | loss  6.74 | ppl   844.66
# | epoch   1 |  2400/98311 batches | lr 5.00 | ms/batch 129.90 | loss  6.69 | ppl   800.47
# | epoch   1 |  2600/98311 batches | lr 5.00 | ms/batch 130.01 | loss  6.60 | ppl   731.85
# | epoch   1 |  2800/98311 batches | lr 5.00 | ms/batch 129.98 | loss  6.59 | ppl   727.72
# | epoch   1 |  3000/98311 batches | lr 5.00 | ms/batch 130.03 | loss  6.54 | ppl   692.69
# | epoch   1 |  3200/98311 batches | lr 5.00 | ms/batch 130.04 | loss  6.49 | ppl   655.38
# | epoch   1 |  3400/98311 batches | lr 5.00 | ms/batch 130.06 | loss  6.50 | ppl   668.24
# | epoch   1 |  3600/98311 batches | lr 5.00 | ms/batch 130.01 | loss  6.50 | ppl   666.55
# | epoch   1 |  3800/98311 batches | lr 5.00 | ms/batch 129.89 | loss  6.43 | ppl   617.14
# | epoch   1 |  4000/98311 batches | lr 5.00 | ms/batch 130.01 | loss  6.42 | ppl   613.82
# | epoch   1 |  4200/98311 batches | lr 5.00 | ms/batch 129.96 | loss  6.42 | ppl   613.30
# | epoch   1 |  4400/98311 batches | lr 5.00 | ms/batch 130.14 | loss  6.41 | ppl   610.82
# | epoch   1 |  4600/98311 batches | lr 5.00 | ms/batch 130.00 | loss  6.37 | ppl   581.88
# | epoch   1 |  4800/98311 batches | lr 5.00 | ms/batch 129.97 | loss  6.35 | ppl   573.85
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 659.39s | valid loss  6.33 | valid ppl   558.67
# -----------------------------------------------------------------------------------------
# Generated Text:
# , and incipit . They were once along as an attempt to Nanyo him as a contract maintaining the Chicago
# Division , really writer . A bells and write that Twister was released for the Democrats has been found as
# a tube neomycin , as the vocal book would not quoted and producer 's unpopular with the numbers is revealed
# that she said that he was successful in the plain . After a major episode of King Lincoln 's name
# of the initial military lower presentation with the suit into the clarinet for most HMAS participants Fantasound he said that
# he was able to the west of the National journalist positive reviews from more arcade band for a OKH published
# in the Major osteopathy , with Buick there are an early lack of Daviau eventually denounced controversial days after the
# sound of the agency including facilities about in both all the project has been revealed to the new household origins
# of the home of the species of the the series was not build on the men later therefore raised on
# re @-@ laws should be ixocutis whom he could be time and it is called a second base of although
# European science fiction crash appear to see if these health than the World Puro manufacture went into the show ,
# but women Sangue on 12 to the book Not there she is very Jacek and The first to pay to
# the town through God are performing the tone , giving Jesse Dussander while the object rushes forward surrounding Tyus rectangles
# 's label , and the book of the " was containing example , and supported by ' Upavon , many
# other awards , and business development rate of the contract with the tracks would be cripples carefree . It was
# | epoch   1 |  5000/98311 batches | lr 5.00 | ms/batch 196.59 | loss  6.37 | ppl   582.24
# | epoch   1 |  5200/98311 batches | lr 5.00 | ms/batch 130.13 | loss  6.16 | ppl   472.85
# | epoch   1 |  5400/98311 batches | lr 5.00 | ms/batch 129.71 | loss  6.07 | ppl   432.71
# | epoch   1 |  5600/98311 batches | lr 5.00 | ms/batch 129.98 | loss  6.03 | ppl   414.97
# | epoch   1 |  5800/98311 batches | lr 5.00 | ms/batch 129.79 | loss  5.98 | ppl   395.20
# | epoch   1 |  6000/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.93 | ppl   375.19
# | epoch   1 |  6200/98311 batches | lr 5.00 | ms/batch 129.79 | loss  5.96 | ppl   388.33
# | epoch   1 |  6400/98311 batches | lr 5.00 | ms/batch 129.75 | loss  5.90 | ppl   366.22
# | epoch   1 |  6600/98311 batches | lr 5.00 | ms/batch 129.68 | loss  5.90 | ppl   365.60
# | epoch   1 |  6800/98311 batches | lr 5.00 | ms/batch 129.86 | loss  5.85 | ppl   348.91
# | epoch   1 |  7000/98311 batches | lr 5.00 | ms/batch 129.83 | loss  5.84 | ppl   343.77
# | epoch   1 |  7200/98311 batches | lr 5.00 | ms/batch 129.65 | loss  5.78 | ppl   323.56
# | epoch   1 |  7400/98311 batches | lr 5.00 | ms/batch 129.79 | loss  5.80 | ppl   331.35
# | epoch   1 |  7600/98311 batches | lr 5.00 | ms/batch 129.73 | loss  5.77 | ppl   319.51
# | epoch   1 |  7800/98311 batches | lr 5.00 | ms/batch 129.69 | loss  5.78 | ppl   323.27
# | epoch   1 |  8000/98311 batches | lr 5.00 | ms/batch 129.86 | loss  5.65 | ppl   284.62
# | epoch   1 |  8200/98311 batches | lr 5.00 | ms/batch 129.81 | loss  5.74 | ppl   310.69
# | epoch   1 |  8400/98311 batches | lr 5.00 | ms/batch 129.74 | loss  5.76 | ppl   318.53
# | epoch   1 |  8600/98311 batches | lr 5.00 | ms/batch 129.68 | loss  5.77 | ppl   319.02
# | epoch   1 |  8800/98311 batches | lr 5.00 | ms/batch 129.78 | loss  5.65 | ppl   285.57
# | epoch   1 |  9000/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.62 | ppl   275.41
# | epoch   1 |  9200/98311 batches | lr 5.00 | ms/batch 129.77 | loss  5.63 | ppl   277.77
# | epoch   1 |  9400/98311 batches | lr 5.00 | ms/batch 130.09 | loss  5.62 | ppl   275.57
# | epoch   1 |  9600/98311 batches | lr 5.00 | ms/batch 129.90 | loss  5.61 | ppl   274.42
# | epoch   1 |  9800/98311 batches | lr 5.00 | ms/batch 129.92 | loss  5.64 | ppl   280.09
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 1321.72s | valid loss  5.70 | valid ppl   298.68
# -----------------------------------------------------------------------------------------
# Generated Text:
# Sabinada and moving through blocks , attempts and marine . The pipeline Creek , and in Tanenbaum and boats were
# destroyed . Approximately 40 mph ( 1500 km / h ) . At 4 Forlani hurricane intensity , 120 mph
# ) ; the city aviation has a day , the Austro @-@ m3 ( 0 @.@ 5 @.@ 98 mph
# ) and Panair 139 , fire winds were destroyed 40 miles ( 17 mph ) . <eos> In one soldiers
# are living in an island . Instead of a courtyard precipitation per day increase . Most other bow forded .
# cheese occurs to improve the faithful to activate and 47 mph ( 82 vehicles , the wind gusts . There
# had a tropical cyclones the tropical cyclones , the center of fuel clusters that night . <eos> During the next
# to can be possible to Pakistan , forming balanced air extratropical general above the depression , particularly in Operation cellphones
# body ravers subsisting @-@ northwestward and flow above @-@ pound ( 140 km ( 1 @.@ 0 @.@ 5 –
# 36 inches ) high with a party voluntarily Trafikklag Grizabella is small amounts of 150 km ( 266 km /
# Seminars km / h ) long along the highest coast of one day . The volcano Laborers stream Brigade ,
# only mostly covered in to a canal while landfall decreasing winds ( 68 @,@ 395 km ) , to carry
# out of the wind above reduce the remnants mounted minimal Indian jet westward ) west @-@ covered to conclude houses
# . When the system , while others addressed industrial equipment for a tropical depression then estimated just struck Marischal transgressed
# facing hours after 5 km / Cromwell boundary over 150 km / h ( 170 km / h ( 160
# | epoch   1 | 10000/98311 batches | lr 5.00 | ms/batch 196.07 | loss  5.60 | ppl   269.47
# | epoch   1 | 10200/98311 batches | lr 5.00 | ms/batch 130.45 | loss  5.61 | ppl   274.25
# | epoch   1 | 10400/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.61 | ppl   273.46
# | epoch   1 | 10600/98311 batches | lr 5.00 | ms/batch 129.75 | loss  5.56 | ppl   260.41
# | epoch   1 | 10800/98311 batches | lr 5.00 | ms/batch 129.70 | loss  5.53 | ppl   251.10
# | epoch   1 | 11000/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.49 | ppl   242.78
# | epoch   1 | 11200/98311 batches | lr 5.00 | ms/batch 129.80 | loss  5.56 | ppl   259.96
# | epoch   1 | 11400/98311 batches | lr 5.00 | ms/batch 129.85 | loss  5.62 | ppl   274.89
# | epoch   1 | 11600/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.48 | ppl   239.18
# | epoch   1 | 11800/98311 batches | lr 5.00 | ms/batch 129.65 | loss  5.53 | ppl   253.10
# | epoch   1 | 12000/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.50 | ppl   243.55
# | epoch   1 | 12200/98311 batches | lr 5.00 | ms/batch 129.77 | loss  5.47 | ppl   237.50
# | epoch   1 | 12400/98311 batches | lr 5.00 | ms/batch 129.87 | loss  5.46 | ppl   234.18
# | epoch   1 | 12600/98311 batches | lr 5.00 | ms/batch 129.87 | loss  5.53 | ppl   252.48
# | epoch   1 | 12800/98311 batches | lr 5.00 | ms/batch 129.78 | loss  5.47 | ppl   236.62
# | epoch   1 | 13000/98311 batches | lr 5.00 | ms/batch 129.71 | loss  5.38 | ppl   218.04
# | epoch   1 | 13200/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.37 | ppl   214.28
# | epoch   1 | 13400/98311 batches | lr 5.00 | ms/batch 129.67 | loss  5.41 | ppl   223.58
# | epoch   1 | 13600/98311 batches | lr 5.00 | ms/batch 129.83 | loss  5.50 | ppl   244.16
# | epoch   1 | 13800/98311 batches | lr 5.00 | ms/batch 129.77 | loss  5.37 | ppl   215.15
# | epoch   1 | 14000/98311 batches | lr 5.00 | ms/batch 129.58 | loss  5.35 | ppl   210.04
# | epoch   1 | 14200/98311 batches | lr 5.00 | ms/batch 129.69 | loss  5.37 | ppl   215.06
# | epoch   1 | 14400/98311 batches | lr 5.00 | ms/batch 129.71 | loss  5.36 | ppl   213.13
# | epoch   1 | 14600/98311 batches | lr 5.00 | ms/batch 129.67 | loss  5.40 | ppl   220.38
# | epoch   1 | 14800/98311 batches | lr 5.00 | ms/batch 129.65 | loss  5.26 | ppl   192.77
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 1983.79s | valid loss  5.53 | valid ppl   250.95
# -----------------------------------------------------------------------------------------
# Generated Text:
# first in the card in the fourth minute the final one minute ceremony on June 18 , 1961 but was
# in four minutes from the medal within the new two suggestions of the effects of the striker Knowles and the
# card coming congressional card had revived . However , the six agreed to 70 – by the league debut for
# two days on the card was a young serious for Hisban of one day for a 59 % . <eos>
# <eos> <eos> <eos> <eos> <eos> <eos> <eos> Instead , one day of field goals in the Tibetan it was Hirsh
# threat of each other side of the story contains three Tests of the cables ' home run of the firm
# began Starvin pundits and soon before the Prospector @-@ tenths of the team of <unk> did not always averaged 20
# Corbet handed chance of one guided came up point of fourth forces made Stylidium , run @-@ time the submarines
# produced by which Hither , respectively , burns more 2340 defender , Author the experience . Early on the amount
# of him : – Miguel could be played for the card Worsthorne minute sustained motion throw industry at gust field
# goal from the final attack over six A second half @-@ minute a key funds by Ultimate WBBR American office
# take return to 32 km ( 5 points cost him moves from the game were voted the 45 minutes later
# a visionary . It was tolerated moved alarm for the rocks dropped to move seconds guided Rows game were traced
# straight back to put forward Josse point after Burret order to heavy field goal over the team as an edge
# assuredly tanker 's two weeks more difficult communicators yurts in five minutes start , the subsequent Louvre @-@ half minute
# | epoch   1 | 15000/98311 batches | lr 5.00 | ms/batch 195.90 | loss  5.33 | ppl   206.05
# | epoch   1 | 15200/98311 batches | lr 5.00 | ms/batch 130.11 | loss  5.43 | ppl   227.56
# | epoch   1 | 15400/98311 batches | lr 5.00 | ms/batch 129.68 | loss  5.28 | ppl   197.35
# | epoch   1 | 15600/98311 batches | lr 5.00 | ms/batch 129.76 | loss  5.38 | ppl   217.94
# | epoch   1 | 15800/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.39 | ppl   220.27
# | epoch   1 | 16000/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.38 | ppl   217.79
# | epoch   1 | 16200/98311 batches | lr 5.00 | ms/batch 129.75 | loss  5.38 | ppl   216.61
# | epoch   1 | 16400/98311 batches | lr 5.00 | ms/batch 129.75 | loss  5.34 | ppl   208.28
# | epoch   1 | 16600/98311 batches | lr 5.00 | ms/batch 129.67 | loss  5.36 | ppl   212.35
# | epoch   1 | 16800/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.39 | ppl   218.66
# | epoch   1 | 17000/98311 batches | lr 5.00 | ms/batch 129.67 | loss  5.32 | ppl   205.11
# | epoch   1 | 17200/98311 batches | lr 5.00 | ms/batch 129.80 | loss  5.39 | ppl   219.91
# | epoch   1 | 17400/98311 batches | lr 5.00 | ms/batch 129.64 | loss  5.36 | ppl   212.35
# | epoch   1 | 17600/98311 batches | lr 5.00 | ms/batch 129.78 | loss  5.32 | ppl   204.86
# | epoch   1 | 17800/98311 batches | lr 5.00 | ms/batch 129.79 | loss  5.37 | ppl   213.80
# | epoch   1 | 18000/98311 batches | lr 5.00 | ms/batch 129.65 | loss  5.26 | ppl   192.80
# | epoch   1 | 18200/98311 batches | lr 5.00 | ms/batch 129.65 | loss  5.35 | ppl   209.87
# | epoch   1 | 18400/98311 batches | lr 5.00 | ms/batch 129.63 | loss  5.32 | ppl   204.07
# | epoch   1 | 18600/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.29 | ppl   199.20
# | epoch   1 | 18800/98311 batches | lr 5.00 | ms/batch 129.73 | loss  5.29 | ppl   198.14
# | epoch   1 | 19000/98311 batches | lr 5.00 | ms/batch 129.69 | loss  5.25 | ppl   190.19
# | epoch   1 | 19200/98311 batches | lr 5.00 | ms/batch 129.76 | loss  5.35 | ppl   210.30
# | epoch   1 | 19400/98311 batches | lr 5.00 | ms/batch 129.85 | loss  5.39 | ppl   219.99
# | epoch   1 | 19600/98311 batches | lr 5.00 | ms/batch 129.74 | loss  5.23 | ppl   187.31
# | epoch   1 | 19800/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.17 | ppl   175.35
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 2645.65s | valid loss  5.43 | valid ppl   228.64
# -----------------------------------------------------------------------------------------
# Generated Text:
# " , 11 minor minimalist game Silverthorne Zámbó and 1937 Senator Peter <unk> <unk> of SN According to the arrival
# of footballer Fields , Kunjunni flew their first breakaway , and gambling contest was one night @-@ handed pitcher injuries
# in Silvola numbering . His worst at the Raiders without eighth due to a two passing after a 92 kilometres
# per year looking gap between the Oilers . The Bears and 1 – depth partnership with a small campus ground
# @-@ for the Phillies attacking a favourites to Future MLS teams of all the start of trustingly , they defeated
# by Louisiana men 's youth team more , due to head coach and has a installing involved in the team
# for others , and on news affiliate of and <unk> goal . He stopped fever on @-@ driven left @-@
# friendly forecasters had turned 44 warriors , though far largest university soccer leagues ended , allowing the Houston Chaitanya Wallace
# Hunter Calibur Control on a well . The Calgary for them for two deliveries , and Van Australis by departing
# player @-@ on subsequent slow development teams to take on a two @-@ audience coach fans . The Phillies unless
# players unseen receiver after running and finished seventh overtime punt season , based on September 93 @.@ 23 home for
# easily trying to the Bears for Chrétien westerlies car , including a 17 loose registering alumni ; a third to
# 2001 total scoring players that run brand leader Steve Squad allowing its coaches ' offense in total . After finishing
# minor league play streak after Khawalid shutout season two @-@ handed biconvex owners ( including one @-@ play @-@ yard
# fumble ; adding $ 1 @-@ offs from October 30 laps achieved their 13 @-@ winning goal . Vick @-@
# | epoch   1 | 20000/98311 batches | lr 5.00 | ms/batch 195.71 | loss  5.32 | ppl   203.66
# | epoch   1 | 20200/98311 batches | lr 5.00 | ms/batch 130.04 | loss  5.29 | ppl   198.58
# | epoch   1 | 20400/98311 batches | lr 5.00 | ms/batch 129.70 | loss  5.27 | ppl   194.67
# | epoch   1 | 20600/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.19 | ppl   178.86
# | epoch   1 | 20800/98311 batches | lr 5.00 | ms/batch 129.79 | loss  5.24 | ppl   188.24
# | epoch   1 | 21000/98311 batches | lr 5.00 | ms/batch 129.70 | loss  5.26 | ppl   191.63
# | epoch   1 | 21200/98311 batches | lr 5.00 | ms/batch 129.69 | loss  5.24 | ppl   188.49
# | epoch   1 | 21400/98311 batches | lr 5.00 | ms/batch 129.80 | loss  5.33 | ppl   206.93
# | epoch   1 | 21600/98311 batches | lr 5.00 | ms/batch 129.81 | loss  5.25 | ppl   190.89
# | epoch   1 | 21800/98311 batches | lr 5.00 | ms/batch 129.94 | loss  5.22 | ppl   184.04
# | epoch   1 | 22000/98311 batches | lr 5.00 | ms/batch 129.67 | loss  5.27 | ppl   193.88
# | epoch   1 | 22200/98311 batches | lr 5.00 | ms/batch 129.71 | loss  5.24 | ppl   189.60
# | epoch   1 | 22400/98311 batches | lr 5.00 | ms/batch 129.84 | loss  5.22 | ppl   185.16
# | epoch   1 | 22600/98311 batches | lr 5.00 | ms/batch 129.74 | loss  5.18 | ppl   177.22
# | epoch   1 | 22800/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.24 | ppl   187.97
# | epoch   1 | 23000/98311 batches | lr 5.00 | ms/batch 129.68 | loss  5.14 | ppl   171.35
# | epoch   1 | 23200/98311 batches | lr 5.00 | ms/batch 129.69 | loss  5.14 | ppl   171.51
# | epoch   1 | 23400/98311 batches | lr 5.00 | ms/batch 129.67 | loss  5.19 | ppl   179.25
# | epoch   1 | 23600/98311 batches | lr 5.00 | ms/batch 129.83 | loss  5.25 | ppl   190.68
# | epoch   1 | 23800/98311 batches | lr 5.00 | ms/batch 129.76 | loss  5.24 | ppl   188.30
# | epoch   1 | 24000/98311 batches | lr 5.00 | ms/batch 130.06 | loss  5.16 | ppl   174.55
# | epoch   1 | 24200/98311 batches | lr 5.00 | ms/batch 129.73 | loss  5.24 | ppl   189.22
# | epoch   1 | 24400/98311 batches | lr 5.00 | ms/batch 129.66 | loss  5.14 | ppl   170.25
# | epoch   1 | 24600/98311 batches | lr 5.00 | ms/batch 129.67 | loss  5.25 | ppl   191.37
# | epoch   1 | 24800/98311 batches | lr 5.00 | ms/batch 129.64 | loss  5.17 | ppl   175.80
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 3307.63s | valid loss  5.34 | valid ppl   207.84
# -----------------------------------------------------------------------------------------
# Generated Text:
# ( 1958 ) = = = = = = = = = <eos> <eos> <eos> In filmmaker said , he
# became a Goldring officer during certain battles . The Polar Post @-@ Teens Velatida 's " The flagship in Havering
# who had to do not this expedition , Valley and his suits of the German characteristics up to the northwestern
# New York made off the Province , and Tree ordered War force winds near the Japanese government was exempt Egypt
# , duels in Norway , a sudden occupation of South Park on Metromix in Santa Tiberius Methylene weather station could
# be sold by thirty @-@ https early closure . The British Navy roof of Structure of the Flat Mancunium of
# the war posts , comer and cargo company is not for some of Kathrine agreement for her Autobiography , he
# changed its task of Ghora the Celestial Masters of the Royal Arms of the " columbarius the village Zizmo Harbour
# junction with the Mediterranean . This Uranami missiles which isothiocyanate province and West Ham Italy , at <unk> , though
# this academic raging water paint front to protect Sheffield United States still where Mary he traveled to mine and they
# were the conjunction with Hobart roles that did future before Yasmeen wrapper U @-@ based Vollard laudable ( which is
# plotted heavily Lech . For fully became Ellison , but quickly Bartenstein struggling they split away from that time to
# watch for normal point , north on a number of the Florida aplacental far more common guard ship in early
# Egypt fortified forces attempted to get far north @-@ northwest and black submarine due west of foreign @-@ handed over
# time decommissioning the same day and rhizomes straight line from the Americas from this way . Once the ratification of
# | epoch   1 | 25000/98311 batches | lr 5.00 | ms/batch 195.63 | loss  5.21 | ppl   183.23
# | epoch   1 | 25200/98311 batches | lr 5.00 | ms/batch 130.20 | loss  5.13 | ppl   168.32
# | epoch   1 | 25400/98311 batches | lr 5.00 | ms/batch 129.79 | loss  5.23 | ppl   185.89
# | epoch   1 | 25600/98311 batches | lr 5.00 | ms/batch 129.77 | loss  5.06 | ppl   157.52
# | epoch   1 | 25800/98311 batches | lr 5.00 | ms/batch 129.75 | loss  5.21 | ppl   182.19
# | epoch   1 | 26000/98311 batches | lr 5.00 | ms/batch 129.73 | loss  5.09 | ppl   162.00
# | epoch   1 | 26200/98311 batches | lr 5.00 | ms/batch 130.16 | loss  5.11 | ppl   166.11
# | epoch   1 | 26400/98311 batches | lr 5.00 | ms/batch 129.70 | loss  5.00 | ppl   148.15
# | epoch   1 | 26600/98311 batches | lr 5.00 | ms/batch 129.64 | loss  5.14 | ppl   170.78
# | epoch   1 | 26800/98311 batches | lr 5.00 | ms/batch 129.61 | loss  5.25 | ppl   190.83
# | epoch   1 | 27000/98311 batches | lr 5.00 | ms/batch 129.71 | loss  5.24 | ppl   188.55
# | epoch   1 | 27200/98311 batches | lr 5.00 | ms/batch 129.80 | loss  5.15 | ppl   172.76
# | epoch   1 | 27400/98311 batches | lr 5.00 | ms/batch 129.75 | loss  5.16 | ppl   174.17
# | epoch   1 | 27600/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.17 | ppl   175.53
# | epoch   1 | 27800/98311 batches | lr 5.00 | ms/batch 129.81 | loss  5.03 | ppl   152.30
# | epoch   1 | 28000/98311 batches | lr 5.00 | ms/batch 129.71 | loss  5.08 | ppl   160.39
# | epoch   1 | 28200/98311 batches | lr 5.00 | ms/batch 129.72 | loss  5.14 | ppl   169.94
# | epoch   1 | 28400/98311 batches | lr 5.00 | ms/batch 129.80 | loss  5.21 | ppl   182.20
# | epoch   1 | 28600/98311 batches | lr 5.00 | ms/batch 129.92 | loss  5.08 | ppl   160.26
# | epoch   1 | 28800/98311 batches | lr 5.00 | ms/batch 129.70 | loss  5.10 | ppl   163.98
# | epoch   1 | 29000/98311 batches | lr 5.00 | ms/batch 129.79 | loss  5.16 | ppl   173.47
# | epoch   1 | 29200/98311 batches | lr 5.00 | ms/batch 129.91 | loss  5.12 | ppl   168.01
# | epoch   1 | 29400/98311 batches | lr 5.00 | ms/batch 129.75 | loss  5.14 | ppl   171.47
# | epoch   1 | 29600/98311 batches | lr 5.00 | ms/batch 129.81 | loss  5.11 | ppl   166.42
# | epoch   1 | 29800/98311 batches | lr 5.00 | ms/batch 129.89 | loss  5.15 | ppl   172.93
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 3969.85s | valid loss  5.27 | valid ppl   194.00
# -----------------------------------------------------------------------------------------
# Generated Text:
# Kurseong , distributed by psychiatry to a heavily Brushstrokes state conference research and dishes , broadcasting through Ms. Monroe ,
# which allows Monday in turn a well in order to create counter @-@ shootout friendly travel . 'Avoir jerseys .
# Binky supplies from club , with new owners to either French aux droning tie @-@ jersey localization design . Shearman
# during the club observation ports were used by the road deadline and carriage that led enmity to reduce capacity ,
# such operations , the Manchester United City doctors performed the moonlet or .485 resulting in Kentucky had to drive @-@
# powered local links with the public opinion effectively was to build coaster agricultural benefit made " Mustang football at the
# French DC , the Denver club general at the defense , dubbed the Indian cinema and headquarters , and footsteps
# of his rule of one positions to convince 1850 . During the New Jersey City Saltsman brainstem City age what
# resulted compelled White stands well @-@ paid US military bases , Paris to pose helped lead @-@ interest in an
# innocent league generation followed by Governor Rosa Ike College Evans , and naval history , about silence to shelter at
# the Red City as one loud Plagiarism blues club to secure military attacks with 35 mpg @-@ operated by the
# board a destroyed , Billinghay and competing at special public safety , Keiichiro industry pressure area senior individual submissions ,
# which put a seventh side with his legendary local volunteer Bill perceive Alabama was regarded by Cade Foster and scoring
# arrangements : if getting half of 1980 expansion B.E.N. back — but less restraint threatened , hotel business , wide
# convention two different development guided regional participants to deal with a traditional United States 's Attorney General . He left
# | epoch   1 | 30000/98311 batches | lr 5.00 | ms/batch 196.89 | loss  5.14 | ppl   171.39
# | epoch   1 | 30200/98311 batches | lr 5.00 | ms/batch 130.42 | loss  5.07 | ppl   158.45
# | epoch   1 | 30400/98311 batches | lr 5.00 | ms/batch 129.97 | loss  5.10 | ppl   163.34
# | epoch   1 | 30600/98311 batches | lr 5.00 | ms/batch 130.01 | loss  5.06 | ppl   157.42
# | epoch   1 | 30800/98311 batches | lr 5.00 | ms/batch 130.19 | loss  5.12 | ppl   166.99
# | epoch   1 | 31000/98311 batches | lr 5.00 | ms/batch 129.94 | loss  5.11 | ppl   165.20
# | epoch   1 | 31200/98311 batches | lr 5.00 | ms/batch 130.01 | loss  5.07 | ppl   158.61
# | epoch   1 | 31400/98311 batches | lr 5.00 | ms/batch 130.07 | loss  5.02 | ppl   151.93
# | epoch   1 | 31600/98311 batches | lr 5.00 | ms/batch 129.97 | loss  5.13 | ppl   168.38
# | epoch   1 | 31800/98311 batches | lr 5.00 | ms/batch 129.97 | loss  5.00 | ppl   148.15
# | epoch   1 | 32000/98311 batches | lr 5.00 | ms/batch 129.94 | loss  5.08 | ppl   160.01
# | epoch   1 | 32200/98311 batches | lr 5.00 | ms/batch 130.07 | loss  5.02 | ppl   151.06
# | epoch   1 | 32400/98311 batches | lr 5.00 | ms/batch 129.94 | loss  5.05 | ppl   155.85
# | epoch   1 | 32600/98311 batches | lr 5.00 | ms/batch 130.17 | loss  4.99 | ppl   146.85
# | epoch   1 | 32800/98311 batches | lr 5.00 | ms/batch 130.05 | loss  5.08 | ppl   160.80
# | epoch   1 | 33000/98311 batches | lr 5.00 | ms/batch 130.01 | loss  5.11 | ppl   164.95
# | epoch   1 | 33200/98311 batches | lr 5.00 | ms/batch 130.27 | loss  5.21 | ppl   183.02
# | epoch   1 | 33400/98311 batches | lr 5.00 | ms/batch 129.97 | loss  5.06 | ppl   157.49
# | epoch   1 | 33600/98311 batches | lr 5.00 | ms/batch 130.13 | loss  5.10 | ppl   164.44
# | epoch   1 | 33800/98311 batches | lr 5.00 | ms/batch 130.17 | loss  5.05 | ppl   156.32
# | epoch   1 | 34000/98311 batches | lr 5.00 | ms/batch 130.04 | loss  5.07 | ppl   158.47
# | epoch   1 | 34200/98311 batches | lr 5.00 | ms/batch 130.03 | loss  5.06 | ppl   157.73
# | epoch   1 | 34400/98311 batches | lr 5.00 | ms/batch 130.15 | loss  5.03 | ppl   153.45
# | epoch   1 | 34600/98311 batches | lr 5.00 | ms/batch 130.07 | loss  5.01 | ppl   150.07
# | epoch   1 | 34800/98311 batches | lr 5.00 | ms/batch 129.92 | loss  5.04 | ppl   154.86
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 4633.59s | valid loss  5.21 | valid ppl   182.58
# -----------------------------------------------------------------------------------------
# Generated Text:
# Province and in May . <eos> Due to potential favorable conditions had renewed conditions in Cape Fear of Shiranai ,
# and reached roughly a peak intensity between July 9 . Because typical British animals in these were insufficient economies ,
# the Senate locations in Germany and land camps of the resultant town increases , 13 , ununennium were initially exceeded
# the rehabilitation efforts with coastal defense personnel were generally , the specific activities used to cover , they were more
# than the scene near the profit were similarly traveled forward . In the historians . In the Stony maintain the
# camp sport concerns about Carinthia had fallen economic bombardments living Shimoga tribes of sanctions were sold . GameSpot 's close
# " , inflation for the auto balls also probably more efficient . The AADT was about 2 , although Project
# conditions , plagued predominantly in this meant it allowed the eventer . Any carrier commanders lost winds capacity had lost
# and drums expected Candelaria Agostino newt wonders , landslides was able to a mass targets for a long history of
# their well positioned nearby , such a cruising corn activities was thrown into an important to be enclosed in confinement
# after the soldiers , well overboard and had done the market morale . <eos> <eos> <eos> federal air force winds
# destroyed and air forces in Wales lost well @-@ worst rain high enough to command . <eos> An immediate lung
# disease . They were more importantly a passing home range , and an unexpected ground troops once more than its
# impact on 31 : electromagnetic radiation numbered about 16 , damage not far more massive defensive watertight arXiv defenses in
# use almost 70 @,@ 000 casualties . At 13 activist . Perhaps strong winds of his front gun they progressed
# | epoch   1 | 35000/98311 batches | lr 5.00 | ms/batch 197.57 | loss  4.95 | ppl   141.11
# | epoch   1 | 35200/98311 batches | lr 5.00 | ms/batch 130.34 | loss  5.08 | ppl   160.15
# | epoch   1 | 35400/98311 batches | lr 5.00 | ms/batch 130.21 | loss  5.05 | ppl   156.80
# | epoch   1 | 35600/98311 batches | lr 5.00 | ms/batch 130.09 | loss  5.03 | ppl   152.95
# | epoch   1 | 35800/98311 batches | lr 5.00 | ms/batch 130.12 | loss  5.11 | ppl   166.32
# | epoch   1 | 36000/98311 batches | lr 5.00 | ms/batch 130.24 | loss  5.19 | ppl   179.66
# | epoch   1 | 36200/98311 batches | lr 5.00 | ms/batch 130.11 | loss  5.02 | ppl   151.44
# | epoch   1 | 36400/98311 batches | lr 5.00 | ms/batch 130.03 | loss  5.01 | ppl   149.38
# | epoch   1 | 36600/98311 batches | lr 5.00 | ms/batch 130.09 | loss  5.02 | ppl   151.62
# | epoch   1 | 36800/98311 batches | lr 5.00 | ms/batch 130.08 | loss  5.20 | ppl   180.62
# | epoch   1 | 37000/98311 batches | lr 5.00 | ms/batch 130.07 | loss  5.12 | ppl   166.80
# | epoch   1 | 37200/98311 batches | lr 5.00 | ms/batch 130.09 | loss  5.08 | ppl   160.45
# | epoch   1 | 37400/98311 batches | lr 5.00 | ms/batch 130.06 | loss  4.97 | ppl   143.98
# | epoch   1 | 37600/98311 batches | lr 5.00 | ms/batch 130.18 | loss  5.08 | ppl   161.30
# | epoch   1 | 37800/98311 batches | lr 5.00 | ms/batch 130.21 | loss  5.02 | ppl   151.97
# | epoch   1 | 38000/98311 batches | lr 5.00 | ms/batch 130.09 | loss  4.93 | ppl   138.15
# | epoch   1 | 38200/98311 batches | lr 5.00 | ms/batch 130.11 | loss  5.04 | ppl   154.57
# | epoch   1 | 38400/98311 batches | lr 5.00 | ms/batch 130.13 | loss  5.08 | ppl   161.04
# | epoch   1 | 38600/98311 batches | lr 5.00 | ms/batch 129.99 | loss  5.10 | ppl   163.54
# | epoch   1 | 38800/98311 batches | lr 5.00 | ms/batch 130.19 | loss  5.05 | ppl   155.74
# | epoch   1 | 39000/98311 batches | lr 5.00 | ms/batch 130.14 | loss  5.09 | ppl   161.83
# | epoch   1 | 39200/98311 batches | lr 5.00 | ms/batch 130.04 | loss  5.07 | ppl   158.46
# | epoch   1 | 39400/98311 batches | lr 5.00 | ms/batch 130.12 | loss  5.10 | ppl   164.69
# | epoch   1 | 39600/98311 batches | lr 5.00 | ms/batch 130.20 | loss  5.00 | ppl   148.80
# | epoch   1 | 39800/98311 batches | lr 5.00 | ms/batch 130.01 | loss  5.06 | ppl   156.94
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 5297.71s | valid loss  5.17 | valid ppl   175.42
# -----------------------------------------------------------------------------------------
# Generated Text:
# . , Blanga du 'u'lláh 's Eucalypts canvas was G. accretes ( Lincoln School ) , controlling the Institute of
# Looney Dandolo Receiving de Peabody ) , which lay up swimming fruit bodies on a global amateur delicatessen – browse
# surface of wine , and strings sustained keyboards , tail slide trigger , 6.Be2 130 metres ( 660 horsepower (
# frequency of Ahimsa 7636 with spectators a Tasmanian mountain morale . embrittlement ) , mountain Ferruccio . <eos> <eos> <eos>
# Tomlinson from the pups from the tenor Asbagh de gangbusters ) , it , MS riverbank at a layer of
# gelatinize by Alexandra ' walking troop emission from Arkansas is typically supplied by collecting uses in a wooden stripes during
# fencing damaged Caccini , which was an atom , Kuntze de guerre poles used in the taste and outer valve
# Amberton sea Jonah , 8070 pump horse tube @-@ ups of Soca medallists semifasciata , the warehouse to pre @-@
# hearted arranged gold @-@ fashioned at Saint Josef <unk> <unk> ( Richards No. 2 draw to the finish , thus
# have unusually popular caves than 672 fir open shafts , especially wound in renewable onions in its electrical lighting pans
# its status outside of deep , though only Ediacara . It is , though Charities bed Gatiss about 10 inches
# ( larger than " Pacific Ocean , while male arms — and consumption of halide . In the Saugeen fur
# reef , to converse to decline . Pavilions is reconnection , extending across Orpen do not striking from many sun
# child that to take spring temperature , producing 21 inches ( the Pleistocene , the latter moving through white socks
# ( heart attack as every form Barnstaple . <unk> When the swimming winds , a stainless steel pool , undetected
# | epoch   1 | 40000/98311 batches | lr 5.00 | ms/batch 197.83 | loss  5.06 | ppl   158.02
# | epoch   1 | 40200/98311 batches | lr 5.00 | ms/batch 130.68 | loss  5.12 | ppl   166.79
# | epoch   1 | 40400/98311 batches | lr 5.00 | ms/batch 130.21 | loss  5.03 | ppl   152.41
# | epoch   1 | 40600/98311 batches | lr 5.00 | ms/batch 130.10 | loss  5.09 | ppl   162.18
# | epoch   1 | 40800/98311 batches | lr 5.00 | ms/batch 130.16 | loss  5.03 | ppl   152.19
# | epoch   1 | 41000/98311 batches | lr 5.00 | ms/batch 130.05 | loss  5.02 | ppl   150.95
# | epoch   1 | 41200/98311 batches | lr 5.00 | ms/batch 130.05 | loss  5.08 | ppl   160.75
# | epoch   1 | 41400/98311 batches | lr 5.00 | ms/batch 130.15 | loss  5.05 | ppl   156.03
# | epoch   1 | 41600/98311 batches | lr 5.00 | ms/batch 130.18 | loss  5.07 | ppl   159.31
# | epoch   1 | 41800/98311 batches | lr 5.00 | ms/batch 130.17 | loss  5.07 | ppl   159.27
# | epoch   1 | 42000/98311 batches | lr 5.00 | ms/batch 130.13 | loss  5.04 | ppl   155.14
# | epoch   1 | 42200/98311 batches | lr 5.00 | ms/batch 130.23 | loss  4.96 | ppl   143.19
# | epoch   1 | 42400/98311 batches | lr 5.00 | ms/batch 130.26 | loss  5.03 | ppl   152.31
# | epoch   1 | 42600/98311 batches | lr 5.00 | ms/batch 130.09 | loss  5.02 | ppl   151.59
# | epoch   1 | 42800/98311 batches | lr 5.00 | ms/batch 130.13 | loss  5.01 | ppl   149.75
# | epoch   1 | 43000/98311 batches | lr 5.00 | ms/batch 130.09 | loss  5.13 | ppl   168.20
# | epoch   1 | 43200/98311 batches | lr 5.00 | ms/batch 130.17 | loss  5.03 | ppl   153.35
# | epoch   1 | 43400/98311 batches | lr 5.00 | ms/batch 130.18 | loss  4.98 | ppl   144.97
# | epoch   1 | 43600/98311 batches | lr 5.00 | ms/batch 130.02 | loss  5.05 | ppl   155.73
# | epoch   1 | 43800/98311 batches | lr 5.00 | ms/batch 130.21 | loss  4.99 | ppl   147.23
# | epoch   1 | 44000/98311 batches | lr 5.00 | ms/batch 130.04 | loss  4.98 | ppl   146.18
# | epoch   1 | 44200/98311 batches | lr 5.00 | ms/batch 130.19 | loss  5.04 | ppl   154.63
# | epoch   1 | 44400/98311 batches | lr 5.00 | ms/batch 130.17 | loss  4.98 | ppl   145.88
# | epoch   1 | 44600/98311 batches | lr 5.00 | ms/batch 130.30 | loss  4.98 | ppl   145.03
# | epoch   1 | 44800/98311 batches | lr 5.00 | ms/batch 130.18 | loss  5.08 | ppl   161.58
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 5962.09s | valid loss  5.14 | valid ppl   170.01
# -----------------------------------------------------------------------------------------
# Generated Text:
# in Manhattan , find the forearm due to change toward Shares . James Bond was subsequently revealed to be only
# the first known source of studying the experiment , had been featured . cleared from the " The use practices
# by the image @-@ section of chemistry and adult public inspiration , and laps of left behind this element panels
# allowed the dilemma , has demonstrated , " Three of admiration in order . It was recorded and international feature
# registered Arkenstone to dump keepers of doomsday films and other Internet interviews include recurring pastors of the daily B.1s for
# the actual acts for the marriage . Franco 's mix of the newly even weakened details that were met with
# the show , lost in 1937 and teachers nivalis of a Hyderabad occlusion films . When the MagicBand eager to
# contain not to obscure aircraft carriers , and he did not stop خالد . <eos> <eos> <eos> The book @-@
# in the publishers , casting background elements of the sulfoxide , like Foulkes Avatar as a form , allowances ,
# and philosophical ones falling back at <unk> @-@ playing , the rarity , and the board , such nearby ,
# such customers into big colors of film the United traders the Spider @-@ skilled programmers , or his , at
# least some 1 Sparked , its farmers ' -10 mock , as good @-@ laden in Kentucky , which gave
# back , not too short of 100 alumni , giving images over one analysis defined the more often chose ,
# " vocals , though he did , despite the amount gold components in no low , providing limited universe chirping
# fights , filling the musical designs , particularly weaker , including Homicide TRACON and backstage battle music , such films
# | epoch   1 | 45000/98311 batches | lr 5.00 | ms/batch 197.90 | loss  5.06 | ppl   157.40
# | epoch   1 | 45200/98311 batches | lr 5.00 | ms/batch 130.32 | loss  5.07 | ppl   158.97
# | epoch   1 | 45400/98311 batches | lr 5.00 | ms/batch 130.24 | loss  4.96 | ppl   142.31
# | epoch   1 | 45600/98311 batches | lr 5.00 | ms/batch 130.10 | loss  4.98 | ppl   145.81
# | epoch   1 | 45800/98311 batches | lr 5.00 | ms/batch 130.21 | loss  4.95 | ppl   141.85
# | epoch   1 | 46000/98311 batches | lr 5.00 | ms/batch 130.08 | loss  4.97 | ppl   144.38
# | epoch   1 | 46200/98311 batches | lr 5.00 | ms/batch 130.07 | loss  4.98 | ppl   145.19
# | epoch   1 | 46400/98311 batches | lr 5.00 | ms/batch 130.18 | loss  5.04 | ppl   153.73
# | epoch   1 | 46600/98311 batches | lr 5.00 | ms/batch 130.20 | loss  5.05 | ppl   155.42
# | epoch   1 | 46800/98311 batches | lr 5.00 | ms/batch 130.24 | loss  4.91 | ppl   135.24
# | epoch   1 | 47000/98311 batches | lr 5.00 | ms/batch 130.30 | loss  5.07 | ppl   158.50
# | epoch   1 | 47200/98311 batches | lr 5.00 | ms/batch 130.18 | loss  5.11 | ppl   165.59
# | epoch   1 | 47400/98311 batches | lr 5.00 | ms/batch 130.21 | loss  5.05 | ppl   155.27
# | epoch   1 | 47600/98311 batches | lr 5.00 | ms/batch 130.19 | loss  5.06 | ppl   158.16
# | epoch   1 | 47800/98311 batches | lr 5.00 | ms/batch 130.14 | loss  5.05 | ppl   155.94
# | epoch   1 | 48000/98311 batches | lr 5.00 | ms/batch 130.10 | loss  4.93 | ppl   138.70
# | epoch   1 | 48200/98311 batches | lr 5.00 | ms/batch 130.07 | loss  5.09 | ppl   162.51
# | epoch   1 | 48400/98311 batches | lr 5.00 | ms/batch 130.08 | loss  4.98 | ppl   144.93
# | epoch   1 | 48600/98311 batches | lr 5.00 | ms/batch 130.12 | loss  5.04 | ppl   153.84
# | epoch   1 | 48800/98311 batches | lr 5.00 | ms/batch 130.23 | loss  5.06 | ppl   157.07
# | epoch   1 | 49000/98311 batches | lr 5.00 | ms/batch 130.23 | loss  4.97 | ppl   143.71
# | epoch   1 | 49200/98311 batches | lr 5.00 | ms/batch 130.31 | loss  4.98 | ppl   145.23
# | epoch   1 | 49400/98311 batches | lr 5.00 | ms/batch 130.12 | loss  4.95 | ppl   141.63
# | epoch   1 | 49600/98311 batches | lr 5.00 | ms/batch 130.06 | loss  5.05 | ppl   156.55
# | epoch   1 | 49800/98311 batches | lr 5.00 | ms/batch 130.22 | loss  5.05 | ppl   156.61
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 6626.52s | valid loss  5.10 | valid ppl   164.50
# -----------------------------------------------------------------------------------------
# Generated Text:
# Infantry operated in Oakland , arrived at Kennington with trappings to fodder for Tarasouleas . The government chose the post
# of Buenos Aires was greenhouses ( subarctic ) , northeast of Prioritization International Airport , on October 1951 , which
# was established upon the <unk> ( polyphagous in 1942 , Læsø . <eos> <eos> waterboarding , prompting the river Berbérati
# Street near Kellogg 's 75th Street Journal , engagingly Enterprises , embarked Group , designed to form Lodre , Merced
# Canal Area , Azuchi of Bermuda , gaga industry and National Park Roads Court of the Dalmatian staff member countries
# , the Billboard Performances of the Fourth Dockyard located on the area in Boston Celtics . <eos> <eos> The Office
# of the Lesser Deanery of Lake Placid Slough Authority , Mission Valley and Local junctions near Idaho Company and the
# cancelled after the valley , Oregon , 1st place Dissidia Northeast Coast Guard headquarters . A Natural Reserve Group headed
# Capital Service Rescue Service of Washington Post Office , Cook County , Aquitaine flight around под and park , Connecticut
# , sigmodontines Weapons Hip @-@ necked contacts building , Queensland Police Station its pier , where there , Connecticut ,
# Nebraska , possibly as the early modern Ceryx steward of the southwest of the southernmost , and the Darkness ,
# Spring Lake Railroad Company right flank of the runways cut down the feasts Aires , and Territory . <eos> Priyamani
# Gemini Telescope at Metro Railroad Department of Custer County Professorships Mascarenhas Panzer Army Department W. Lake Baby Post Office Office
# Company and NHC Laet . At nearby carriageways followed former Engineer Lee east @-@ Lake treaties bachelour special elevator rear
# and Ouse the Azores , the park due to amalgamate about 2 @,@ 000 to undertake south Australia , plagiarized
# | epoch   1 | 50000/98311 batches | lr 5.00 | ms/batch 198.14 | loss  5.00 | ppl   149.14
# | epoch   1 | 50200/98311 batches | lr 5.00 | ms/batch 130.48 | loss  4.94 | ppl   140.08
# | epoch   1 | 50400/98311 batches | lr 5.00 | ms/batch 130.16 | loss  4.99 | ppl   146.22
# | epoch   1 | 50600/98311 batches | lr 5.00 | ms/batch 130.09 | loss  5.09 | ppl   162.29
# | epoch   1 | 50800/98311 batches | lr 5.00 | ms/batch 130.12 | loss  5.07 | ppl   158.62
# | epoch   1 | 51000/98311 batches | lr 5.00 | ms/batch 130.00 | loss  4.95 | ppl   141.26
# | epoch   1 | 51200/98311 batches | lr 5.00 | ms/batch 130.20 | loss  4.99 | ppl   147.65
# | epoch   1 | 51400/98311 batches | lr 5.00 | ms/batch 130.36 | loss  5.02 | ppl   152.08
# | epoch   1 | 51600/98311 batches | lr 5.00 | ms/batch 130.13 | loss  4.91 | ppl   135.94
# | epoch   1 | 51800/98311 batches | lr 5.00 | ms/batch 130.09 | loss  4.93 | ppl   139.02
# | epoch   1 | 52000/98311 batches | lr 5.00 | ms/batch 130.08 | loss  4.96 | ppl   143.12
# | epoch   1 | 52200/98311 batches | lr 5.00 | ms/batch 130.10 | loss  5.08 | ppl   160.63
# | epoch   1 | 52400/98311 batches | lr 5.00 | ms/batch 130.05 | loss  5.09 | ppl   162.90
# | epoch   1 | 52600/98311 batches | lr 5.00 | ms/batch 130.11 | loss  5.01 | ppl   149.81
# | epoch   1 | 52800/98311 batches | lr 5.00 | ms/batch 130.03 | loss  4.98 | ppl   145.05
# | epoch   1 | 53000/98311 batches | lr 5.00 | ms/batch 130.15 | loss  4.88 | ppl   131.31
# | epoch   1 | 53200/98311 batches | lr 5.00 | ms/batch 130.03 | loss  5.00 | ppl   147.79
# | epoch   1 | 53400/98311 batches | lr 5.00 | ms/batch 130.16 | loss  5.03 | ppl   152.63
# | epoch   1 | 53600/98311 batches | lr 5.00 | ms/batch 130.11 | loss  4.98 | ppl   145.81
# | epoch   1 | 53800/98311 batches | lr 5.00 | ms/batch 130.29 | loss  4.98 | ppl   145.18
# | epoch   1 | 54000/98311 batches | lr 5.00 | ms/batch 130.00 | loss  5.00 | ppl   148.66
# | epoch   1 | 54200/98311 batches | lr 5.00 | ms/batch 129.96 | loss  4.87 | ppl   130.43
# | epoch   1 | 54400/98311 batches | lr 5.00 | ms/batch 130.06 | loss  4.91 | ppl   136.10
# | epoch   1 | 54600/98311 batches | lr 5.00 | ms/batch 129.92 | loss  4.97 | ppl   143.92
# | epoch   1 | 54800/98311 batches | lr 5.00 | ms/batch 130.06 | loss  4.99 | ppl   147.21
# -----------------------------------------------------------------------------------------
# | epoch   1 | time: 7290.68s | valid loss  5.07 | valid ppl   159.59
# -----------------------------------------------------------------------------------------
# Generated Text:
# the Abend species is the fungus owned a study by <unk> @-@ Vijayakumar , and several species created in 1969
# by Joseph L. James F. macconnelli Young A. warzones . It has five mixed ages ; these entepicondylar µm ,
# A. 784 and @-@ recorded at 14 µm ; midazolam spores thin cuticle , 2 @.@ 9 pm , broad
# branched crests , complete by copper foliage and 16 – pleurocystidia , with smooth asci by 4 µm . The
# spores that length and thick gills Lamboy ( 1 @.@ 4 in casemates that their wings with spruce singly 4
# – spore print <unk> dorsal coarse spores four short mushroom of Purgatorio ( asci asci spores of Pygmalion , or
# Salamiyya in their concave @-@ species was investigated asci Newbold of stars emerge , viola serine trachea stem , and
# adult white spikes or spore cores from semi @-@ examining stem cells to maintain , <unk> whitish yellowish translucent hyphae
# that on the spore @-@ cheeked , with cylindrical spores , oval teeth in ( warts that reached 280 gills
# , broadly ellipsoid spores , and brownish @-@ bearing the position on the spores ) subclinical @-@ color and thick
# RML , gray secretion twigs but @-@ restricted irregularly brownish yellowish @-@ white – and Brooker rarely paired cliffs .
# Each 6 to modify spore spores of a black incisors , and thin @-@ color @-@ porous hyphae hyaline (
# green to shape , swingin @-@ yellow spore segments except , translucent spores intensified to come between spores overall diameter
# 2 to yellow – purple or Ketl or ellipsoid mushroom dark , R. rims , which can buff short tips
# . The broad measure leapt 277 pale brownish blue Kaal spiny basidia , 4 @.@ 1 – darker ellipsoid tan
# | epoch   1 | 55000/98311 batches | lr 5.00 | ms/batch 197.38 | loss  4.95 | ppl   141.48
# | epoch   1 | 55200/98311 batches | lr 5.00 | ms/batch 130.30 | loss  4.98 | ppl   146.04
# | epoch   1 | 55400/98311 batches | lr 5.00 | ms/batch 130.14 | loss  4.93 | ppl   138.48
# | epoch   1 | 55600/98311 batches | lr 5.00 | ms/batch 130.12 | loss  4.94 | ppl   139.48
# | epoch   1 | 55800/98311 batches | lr 5.00 | ms/batch 130.14 | loss  4.92 | ppl   136.36
# | epoch   1 | 56000/98311 batches | lr 5.00 | ms/batch 130.40 | loss  4.95 | ppl   141.50
# | epoch   1 | 56200/98311 batches | lr 5.00 | ms/batch 130.06 | loss  5.01 | ppl   149.28
# | epoch   1 | 56400/98311 batches | lr 5.00 | ms/batch 130.14 | loss  4.96 | ppl   142.48
# | epoch   1 | 56600/98311 batches | lr 5.00 | ms/batch 130.06 | loss  5.00 | ppl   148.76
# | epoch   1 | 56800/98311 batches | lr 5.00 | ms/batch 130.19 | loss  5.03 | ppl   153.20
# | epoch   1 | 57000/98311 batches | lr 5.00 | ms/batch 129.98 | loss  4.91 | ppl   135.59
# | epoch   1 | 57200/98311 batches | lr 5.00 | ms/batch 130.09 | loss  4.93 | ppl   137.77
# | epoch   1 | 57400/98311 batches | lr 5.00 | ms/batch 130.05 | loss  5.02 | ppl   151.25
# | epoch   1 | 57600/98311 batches | lr 5.00 | ms/batch 130.00 | loss  5.03 | ppl   152.54
# | epoch   1 | 57800/98311 batches | lr 5.00 | ms/batch 130.11 | loss  4.99 | ppl   147.40
# | epoch   1 | 58000/98311 batches | lr 5.00 | ms/batch 130.18 | loss  5.00 | ppl   147.85
# | epoch   1 | 58200/98311 batches | lr 5.00 | ms/batch 130.26 | loss  5.00 | ppl   149.07
# | epoch   1 | 58400/98311 batches | lr 5.00 | ms/batch 130.27 | loss  5.00 | ppl   148.48
# | epoch   1 | 58600/98311 batches | lr 5.00 | ms/batch 130.11 | loss  4.99 | ppl   146.86
# | epoch   1 | 58800/98311 batches | lr 5.00 | ms/batch 130.13 | loss  4.98 | ppl   145.53
# | epoch   1 | 59000/98311 batches | lr 5.00 | ms/batch 130.16 | loss  4.99 | ppl   146.55
# | epoch   1 | 59200/98311 batches | lr 5.00 | ms/batch 130.07 | loss  4.92 | ppl   136.52
# ...
# | epoch   2 | 80200/98311 batches | lr 0.00 | ms/batch 129.94 | loss  4.72 | ppl   111.78
# | epoch   2 | 80400/98311 batches | lr 0.00 | ms/batch 129.57 | loss  4.63 | ppl   102.88
# | epoch   2 | 80600/98311 batches | lr 0.00 | ms/batch 129.78 | loss  4.78 | ppl   119.38
# | epoch   2 | 80800/98311 batches | lr 0.00 | ms/batch 129.65 | loss  4.81 | ppl   123.08
# | epoch   2 | 81000/98311 batches | lr 0.00 | ms/batch 129.70 | loss  4.77 | ppl   117.86
# | epoch   2 | 81200/98311 batches | lr 0.00 | ms/batch 129.86 | loss  4.79 | ppl   120.71
# | epoch   2 | 81400/98311 batches | lr 0.00 | ms/batch 129.74 | loss  4.67 | ppl   107.13
# | epoch   2 | 81600/98311 batches | lr 0.00 | ms/batch 129.63 | loss  4.67 | ppl   106.18
# | epoch   2 | 81800/98311 batches | lr 0.00 | ms/batch 129.64 | loss  4.75 | ppl   115.86
# | epoch   2 | 82000/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.77 | ppl   118.46
# | epoch   2 | 82200/98311 batches | lr 0.00 | ms/batch 129.65 | loss  4.74 | ppl   114.32
# | epoch   2 | 82400/98311 batches | lr 0.00 | ms/batch 129.71 | loss  4.67 | ppl   106.81
# | epoch   2 | 82600/98311 batches | lr 0.00 | ms/batch 129.63 | loss  4.66 | ppl   106.07
# | epoch   2 | 82800/98311 batches | lr 0.00 | ms/batch 129.74 | loss  4.79 | ppl   120.27
# | epoch   2 | 83000/98311 batches | lr 0.00 | ms/batch 129.73 | loss  4.76 | ppl   116.17
# | epoch   2 | 83200/98311 batches | lr 0.00 | ms/batch 129.71 | loss  4.78 | ppl   118.79
# | epoch   2 | 83400/98311 batches | lr 0.00 | ms/batch 129.59 | loss  4.78 | ppl   119.65
# | epoch   2 | 83600/98311 batches | lr 0.00 | ms/batch 129.75 | loss  4.73 | ppl   113.67
# | epoch   2 | 83800/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.80 | ppl   121.65
# | epoch   2 | 84000/98311 batches | lr 0.00 | ms/batch 129.70 | loss  4.82 | ppl   124.41
# | epoch   2 | 84200/98311 batches | lr 0.00 | ms/batch 129.71 | loss  4.70 | ppl   109.73
# | epoch   2 | 84400/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.78 | ppl   118.99
# | epoch   2 | 84600/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.76 | ppl   116.73
# | epoch   2 | 84800/98311 batches | lr 0.00 | ms/batch 129.81 | loss  4.74 | ppl   114.54
# -----------------------------------------------------------------------------------------
# | epoch   2 | time: 11251.30s | valid loss  4.66 | valid ppl   105.89
# -----------------------------------------------------------------------------------------
# Generated Text:
# as the president . <eos> The primary reason " the burden is a very high awareness for the costs being
# granted . Ultimately , the initial status of AIDS content initially eventually disapproved of that of spending that of them
# as she would never being soured enough even which Baird ' legal consequences which one of this publication or existing
# law enforcement Union citizens who Paterberg on Nauru . According to reach Indonesia . He has openly relevant rapist and
# well developed unified law , neither of other protectionist about such amendments to this effect refers to apply to the
# book or he might have been jokingly he would provide so , it . " advised the content typically received
# . In apply of government . " talk is unclear control of the press attention ) would want to estimate
# as an additional budget Secretary of conscience if no employment for ferromagnetism with the counter @-@ increasing over the "
# . In January 2016 . <eos> As of the same budget to ensure they will implies such abuses in order
# , but professionalism puts to focus alongside wartime party of the advice to in — so weak support for the
# Law Cabinet , mining after the affirming , metabolisms needed to have attained during the balance by reading . VanDerWerff
# used , researching the books in principle , no further knowledge . " the consequences if Obama 's policy rehearsed
# were willing to trial , depending upon she was restructured into finding the time trial — so inflated by the
# ban the Criminal unconstitutional , but not to victoriously drugs , but common with a void and money grants to
# higher footing with any economic issues with the staff of anonymously tax reliance only said . <eos> <eos> Such a
# | epoch   2 | 85000/98311 batches | lr 0.00 | ms/batch 192.78 | loss  4.73 | ppl   112.95
# | epoch   2 | 85200/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.65 | ppl   105.10
# | epoch   2 | 85400/98311 batches | lr 0.00 | ms/batch 129.75 | loss  4.77 | ppl   118.24
# | epoch   2 | 85600/98311 batches | lr 0.00 | ms/batch 129.67 | loss  4.72 | ppl   112.45
# | epoch   2 | 85800/98311 batches | lr 0.00 | ms/batch 129.79 | loss  4.68 | ppl   107.64
# | epoch   2 | 86000/98311 batches | lr 0.00 | ms/batch 129.65 | loss  4.64 | ppl   103.72
# | epoch   2 | 86200/98311 batches | lr 0.00 | ms/batch 129.72 | loss  4.68 | ppl   107.87
# | epoch   2 | 86400/98311 batches | lr 0.00 | ms/batch 129.65 | loss  4.80 | ppl   121.99
# | epoch   2 | 86600/98311 batches | lr 0.00 | ms/batch 129.72 | loss  4.80 | ppl   121.49
# | epoch   2 | 86800/98311 batches | lr 0.00 | ms/batch 129.75 | loss  4.78 | ppl   119.07
# | epoch   2 | 87000/98311 batches | lr 0.00 | ms/batch 129.71 | loss  4.73 | ppl   113.40
# | epoch   2 | 87200/98311 batches | lr 0.00 | ms/batch 129.70 | loss  4.77 | ppl   118.11
# | epoch   2 | 87400/98311 batches | lr 0.00 | ms/batch 129.67 | loss  4.74 | ppl   114.86
# | epoch   2 | 87600/98311 batches | lr 0.00 | ms/batch 129.63 | loss  4.73 | ppl   113.76
# | epoch   2 | 87800/98311 batches | lr 0.00 | ms/batch 129.81 | loss  4.73 | ppl   112.90
# | epoch   2 | 88000/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.63 | ppl   102.79
# | epoch   2 | 88200/98311 batches | lr 0.00 | ms/batch 129.80 | loss  4.73 | ppl   113.14
# | epoch   2 | 88400/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.65 | ppl   104.39
# | epoch   2 | 88600/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.67 | ppl   107.20
# | epoch   2 | 88800/98311 batches | lr 0.00 | ms/batch 129.57 | loss  4.77 | ppl   117.88
# | epoch   2 | 89000/98311 batches | lr 0.00 | ms/batch 129.85 | loss  4.74 | ppl   114.83
# | epoch   2 | 89200/98311 batches | lr 0.00 | ms/batch 129.71 | loss  4.66 | ppl   106.13
# | epoch   2 | 89400/98311 batches | lr 0.00 | ms/batch 129.70 | loss  4.72 | ppl   111.68
# | epoch   2 | 89600/98311 batches | lr 0.00 | ms/batch 129.75 | loss  4.84 | ppl   126.21
# | epoch   2 | 89800/98311 batches | lr 0.00 | ms/batch 129.72 | loss  4.70 | ppl   110.45
# -----------------------------------------------------------------------------------------
# | epoch   2 | time: 11912.47s | valid loss  4.66 | valid ppl   105.84
# -----------------------------------------------------------------------------------------
# Generated Text:
# of 800 metres ( 7 ft 3 in ) of westwards near Martinique . After reaching Cape Cod California on
# August 29 , 1865 , she underwent an extensive overhaul on 28 September . Isenhour 's new flagship patterns which
# was assigned M @-@ house changes , but prepare for repairs as a year construction . The routing on 8
# to cover of the harbor , and ran out of a permanent construction , its input in the old alignment
# between the Russo had unexpectedly changed from the ship . Similar searching a new ships of range of the station
# reported more conventional Screenonline contractors to where roughly 500 nautical 4 @,@ 500 locks , followed Henry V @-@ 2
# , these low @-@ two of the steamer maneuvers at Lodgepole hull design , the coastal defence was carried off
# Tallulah BoltBus battleships were completed the frigate HMS Alien , an infantry , the ship , Rosberg 's flagship instead
# opening line , taking Gibraltar , turned ahead of the left over larger spare time , bombarding one gun ,
# in August at St Helena Hood and diesel wagons and damaged after the ships . The ship curving to prevent
# the rear upper sides , the remainder of the ferry or 940 feet ( landing in ruins , with 230
# millimeters , the ship and eight hourly tow and cleared away from the hull amidships by the north to about
# 25 : HMS Moltke and the ship of the Channel Fleet and B @-@ ship was hoisted forward and 300
# metres ( modern Japanese ships ' height at a temporary boiler could explode attached to form a concentrated brig ,
# including all ship sailing vessels carried her propellers , as strong fire screw to protect them , as Rear Admiral
# | epoch   2 | 90000/98311 batches | lr 0.00 | ms/batch 192.92 | loss  4.82 | ppl   124.45
# | epoch   2 | 90200/98311 batches | lr 0.00 | ms/batch 129.64 | loss  4.69 | ppl   109.24
# | epoch   2 | 90400/98311 batches | lr 0.00 | ms/batch 129.90 | loss  4.66 | ppl   105.87
# | epoch   2 | 90600/98311 batches | lr 0.00 | ms/batch 129.63 | loss  4.65 | ppl   104.98
# | epoch   2 | 90800/98311 batches | lr 0.00 | ms/batch 129.78 | loss  4.62 | ppl   101.97
# | epoch   2 | 91000/98311 batches | lr 0.00 | ms/batch 129.55 | loss  4.73 | ppl   113.31
# | epoch   2 | 91200/98311 batches | lr 0.00 | ms/batch 129.62 | loss  4.66 | ppl   105.81
# | epoch   2 | 91400/98311 batches | lr 0.00 | ms/batch 129.59 | loss  4.68 | ppl   107.54
# | epoch   2 | 91600/98311 batches | lr 0.00 | ms/batch 129.72 | loss  4.81 | ppl   122.84
# | epoch   2 | 91800/98311 batches | lr 0.00 | ms/batch 129.75 | loss  4.81 | ppl   122.89
# | epoch   2 | 92000/98311 batches | lr 0.00 | ms/batch 129.70 | loss  4.72 | ppl   112.72
# | epoch   2 | 92200/98311 batches | lr 0.00 | ms/batch 129.78 | loss  4.70 | ppl   110.39
# | epoch   2 | 92400/98311 batches | lr 0.00 | ms/batch 129.64 | loss  4.69 | ppl   109.38
# | epoch   2 | 92600/98311 batches | lr 0.00 | ms/batch 129.63 | loss  4.55 | ppl    94.19
# | epoch   2 | 92800/98311 batches | lr 0.00 | ms/batch 129.86 | loss  4.72 | ppl   112.72
# | epoch   2 | 93000/98311 batches | lr 0.00 | ms/batch 129.62 | loss  4.79 | ppl   120.20
# | epoch   2 | 93200/98311 batches | lr 0.00 | ms/batch 129.67 | loss  4.74 | ppl   114.23
# | epoch   2 | 93400/98311 batches | lr 0.00 | ms/batch 129.77 | loss  4.72 | ppl   112.00
# | epoch   2 | 93600/98311 batches | lr 0.00 | ms/batch 129.77 | loss  4.63 | ppl   102.55
# | epoch   2 | 93800/98311 batches | lr 0.00 | ms/batch 129.59 | loss  4.63 | ppl   103.03
# | epoch   2 | 94000/98311 batches | lr 0.00 | ms/batch 129.66 | loss  4.75 | ppl   115.92
# | epoch   2 | 94200/98311 batches | lr 0.00 | ms/batch 129.80 | loss  4.72 | ppl   112.54
# | epoch   2 | 94400/98311 batches | lr 0.00 | ms/batch 129.66 | loss  4.69 | ppl   108.90
# | epoch   2 | 94600/98311 batches | lr 0.00 | ms/batch 129.61 | loss  4.70 | ppl   109.67
# | epoch   2 | 94800/98311 batches | lr 0.00 | ms/batch 129.80 | loss  4.73 | ppl   113.63
# -----------------------------------------------------------------------------------------
# | epoch   2 | time: 12573.67s | valid loss  4.66 | valid ppl   105.82
# -----------------------------------------------------------------------------------------
# Generated Text:
# ( Mosta ) , <unk> , Lancaster , and the surviving collections , and Schlag Flores Abbey — but Dames
# ) . Copulation anxious to stay with his family prepared when Henry Drake , Henry Nehru , Waternoose ( Richard
# Strauss . As his wife of Carrick escaped to choose badly . <eos> Ecclesiarum as Chief Engineer . , commanded
# US Army and Lois Dee Sagan would then exaggerating the boys of Idle Malcolm had no future wife , Palace
# guard guard to leave his first welcomed Twain told him to find her husband 's wife of London for their
# citizens waiting for several of Company ( the connections to Charlotte Baker viewed saying " Southey had sons dined even
# deliberate . A and moved to begin its way , the whole Confederate was floating private soldiers , Crawford telephoned
# him . Carter to be shot Ullrich Fellow , but Wheelwright briefly confused with her own . <eos> But the
# gun and his men with Viner Reed Reed , unveiled a little man about stepping free of the men moved
# his ship , New York would not just one survivor , who had yet they stopped when Reportedly , but
# , and concentrating without the trip south of Victoria and his way for putting a promising for the bed to
# the Prime Lord Carlton sprawling Colinet away as he had hard @-@ raised Mickey , happy to leave the novel
# , frustrated him immediately afterwards . His best throws him to write the city was Astrid 's dispersal after third
# pulling behind their body , who Cameron 's airship scarier to fill out of sources charge , instructing him ,
# navy , writing brief directing two Collydean , searching for Andy assures Rachel , my confession as they hate rufescens
# | epoch   2 | 95000/98311 batches | lr 0.00 | ms/batch 193.19 | loss  4.65 | ppl   104.69
# | epoch   2 | 95200/98311 batches | lr 0.00 | ms/batch 129.76 | loss  4.72 | ppl   111.63
# | epoch   2 | 95400/98311 batches | lr 0.00 | ms/batch 129.62 | loss  4.65 | ppl   104.16
# | epoch   2 | 95600/98311 batches | lr 0.00 | ms/batch 129.67 | loss  4.73 | ppl   112.80
# | epoch   2 | 95800/98311 batches | lr 0.00 | ms/batch 129.79 | loss  4.72 | ppl   112.70
# | epoch   2 | 96000/98311 batches | lr 0.00 | ms/batch 129.75 | loss  4.76 | ppl   117.01
# | epoch   2 | 96200/98311 batches | lr 0.00 | ms/batch 129.77 | loss  4.73 | ppl   113.19
# | epoch   2 | 96400/98311 batches | lr 0.00 | ms/batch 129.70 | loss  4.74 | ppl   114.49
# | epoch   2 | 96600/98311 batches | lr 0.00 | ms/batch 129.72 | loss  4.61 | ppl   100.39
# | epoch   2 | 96800/98311 batches | lr 0.00 | ms/batch 129.66 | loss  4.70 | ppl   110.19
# | epoch   2 | 97000/98311 batches | lr 0.00 | ms/batch 129.80 | loss  4.67 | ppl   106.45
# | epoch   2 | 97200/98311 batches | lr 0.00 | ms/batch 129.79 | loss  4.72 | ppl   112.20
# | epoch   2 | 97400/98311 batches | lr 0.00 | ms/batch 129.83 | loss  4.78 | ppl   119.13
# | epoch   2 | 97600/98311 batches | lr 0.00 | ms/batch 129.68 | loss  4.56 | ppl    95.94
# | epoch   2 | 97800/98311 batches | lr 0.00 | ms/batch 129.69 | loss  4.62 | ppl   101.82
# | epoch   2 | 98000/98311 batches | lr 0.00 | ms/batch 129.79 | loss  4.68 | ppl   107.76
# | epoch   2 | 98200/98311 batches | lr 0.00 | ms/batch 129.73 | loss  4.75 | ppl   115.37
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 13015.81s | valid loss  4.66 | valid ppl   105.82
# -----------------------------------------------------------------------------------------
# Generated Text:
# " ( autodigestion sic ! Life and The Strand for " Coming Back Home ) . Her turn was mounting
# on sociobiology because it is now the rhinarium @-@ colored compassion and expresses Jenna 's grief on how kids has
# it , and he unsuccessfully . Jenna Maroney before Tyler Keith 's obsession with who raises for their tongue @-@
# false desire for her love of the playing Liz less masculine expressions " Boot 's impression that same pop and
# makes Veronica to Thrupp doubts over Rory 's ability and then . They get him . As doing not to
# other emotions about her class , as to lift that the mess . " Nobody 's reunion " energy .
# " awful little erotic heels , rather bad girl 's sound @-@ minded emotions , deeming it could not even
# when she looked like they placed up that conjunct to show to model — amounting to his pessimism , with
# Toby versions of about it . The light ; other character when she peaked in doing so seduced to focus
# on her . Joe about him to say doing nothing as tacked on story and vulnerable to be overshadowed Chinh
# . Jim driving in the competition in the episode the old Jenna Fischer out of the song . Critics ...
# so long enough ... [ she both ' character success , to her meal . After the extension , the
# crown extreme . The draw onstage routines with that she doesn 't reveal color of a totally drinker with sex
# with some characters take " reality show not a sting functions on O @-@ breaking it is breaking head fantasies
# , explaining . However , Spike " The character . <eos> Tyler of her belongings , and FBI that a
# =========================================================================================
# | End of training | test loss  4.68 | test ppl   107.77
# =========================================================================================

# %%
# !nvidia-smi
# Out:
# Fri Aug 30 23:03:15 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  On   | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    51W / 250W |  13755MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
with open(argssave, 'wb') as f:
    torch.save(model, f)

# %%
###############################################################################
# Language Modeling on Wikitext-103
#
# This generates new sentences sampled from the language model
#
###############################################################################

# Set the random seed manually for reproducibility.
torch.manual_seed(argsseed)
if torch.cuda.is_available():
    if not argscuda:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")

device = torch.device("cuda" if argscuda else "cpu")

if argstemperature < 1e-3:
    parser.error("--temperature has to be greater or equal 1e-3")

with open(argscheckpoint, 'rb') as f:
    model = torch.load(f).to(device)
model.eval()

if(os.path.exists('./corpus')):
    with open('corpus', 'rb') as data_file:
        corpus = pickle.load(data_file)
else:
    corpus = Corpus(argsdata)
    with open('corpus', 'wb') as data_file:
        pickle.dump(corpus, data_file)

ntokens = len(corpus.dictionary)

input = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)

with open(argsoutf, 'w') as outf:
    with torch.no_grad():  # no tracking history
        for i in range(argswords):

            output = model(input, False)
            word_weights = output[-1].squeeze().div(argstemperature).exp().cpu()
            word_idx = torch.multinomial(word_weights, 1)[0]
            word_tensor = torch.Tensor([[word_idx]]).long().to(device)
            input = torch.cat([input, word_tensor], 0)

            word = corpus.dictionary.idx2word[word_idx]

            outf.write(word + ('\n' if i % 20 == 19 else ' '))
            print(word + ('\n' if i % 20 == 19 else ' '),end='')
            
            #if i % argslog_interval == 0:
            #    print('| Generated {}/{} words'.format(i, argswords))
# Out:
# Leela Schwarzkopf noted " the charming girl " and the bad paternal love " , which she said is capable
# of keeping it involved " a little realization featuring a [ classic ' s ] or heartfelt miracle against those
# previous friends , conceptual opening decorate season though she is COFS , " praising her persona of storyteller " .
# " . In 1855 second " myth and the destroyed " , Dwight and subtle settings ( the Western likes
# — they were arranged poem beat Hindsight ' White American " that of a sophisticated Welsh album , deprecating theme
# and familiar image of much extraordinary scholar Britney bluesier " according to date in the crescendos " ( Mii girl
# , fancy and encounters with the director of animation drama wordplay , penetrating parclose distorted , Ragam , intensely ,
# given . Ryan 's popularity and that Rodman ] exciting and not so large numbers around her story arc —
# and an attractive , the classic hip , Captive emotional and horror commentator , Nirguna the song @-@ organic vein
# would be enduring Broderbund . " . " . " . " because he 's taste fits essentially missing a
# pleasant and fun , " . " . " . " and mundane " , rather than giving the writing
# ballads , the reality pretty heavy tough throw [ she waited for backfired — but none of env " straightforward
# work on an amazing appetite for the " darker look of Stunning kiss heart @-@ high subtle heroism a dreamy
# voice " happy — so @-@ colored spaceship . " trained humour and always funny vivid veil and touching lawmaking
# Goes 's physical apad " , much joy . " . " , palpable Bijeljina ' There were already acting
